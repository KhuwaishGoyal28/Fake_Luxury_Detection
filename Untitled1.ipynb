# %%
import google.generativeai as genai
import speech_recognition as sr
import pyttsx3
import webbrowser
import os

# 🔹 Configure Gemini AI
genai.configure(api_key="AIzaSyAyXEBdGOxciCDSItQRhru2BbNfbvZtyRs")
model = genai.GenerativeModel("gemini-1.5-pro")

# 🔹 Setup Text-to-Speech (TTS)
engine = pyttsx3.init()
engine.setProperty('rate', 170)  # Speaking speed
engine.setProperty('voice', engine.getProperty('voices')[0].id)  # Select voice

# 🔹 Function to Speak
def speak(text):
    engine.say(text)
    engine.runAndWait()

# 🔹 Function to Listen
def listen():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("🎙 Listening...")
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)
    try:
        command = recognizer.recognize_google(audio)
        print(f"🟢 You: {command}")
        return command.lower()
    except sr.UnknownValueError:
        return "I couldn't understand that."
    except sr.RequestError:
        return "API request failed."

# 🔹 Function to Get AI Response
def ask_jarvis(question):
    response = model.generate_content(question)
    return response.text

# 🔹 Function to Open Websites
def open_website(command):
    sites = {
        "youtube": "https://youtube.com",
        "google": "https://google.com",
        "github": "https://github.com",
        "facebook": "https://facebook.com"
    }
    for site in sites:
        if site in command:
            speak(f"Opening {site}")
            webbrowser.open(sites[site])
            return True
    return False

# 🔹 Function to Open System Apps
def open_app(command):
    apps = {
        "notepad": "notepad.exe",
        "calculator": "calc.exe"
    }
    for app in apps:
        if app in command:
            speak(f"Opening {app}")
            os.system(apps[app])
            return True
    return False

# 🔹 Main Loop
speak("Hello Sir, I am J.A.R.V.I.S. How can I assist you?")
while True:
    command = listen()

    if "exit" in command or "stop" in command:
        speak("Goodbye Sir!")
        break

    elif open_website(command):
        continue

    elif open_app(command):
        continue

    else:
        response = ask_jarvis(command)
        print(f"🔵 J.A.R.V.I.S.: {response}")
        speak(response)
# Out:
# 🎙 Listening...
# 🟢 You: open calculator
# 🎙 Listening...
# 🔵 J.A.R.V.I.S.: Please tell me what you didn't understand.  I need more context to help you.  Were you referring to something I said previously, or something else entirely?  The more information you give me, the better I can assist you.
#
# 🎙 Listening...
# 🟢 You: open YouTube
# 🎙 Listening...
# 🟢 You: phone kar le phone exit

# %%
import google.generativeai as genai
import speech_recognition as sr
import pyttsx3
import webbrowser
import os
import keyboard
import pyautogui
import customtkinter as ctk
import requests
import pyperclip

# Configure Gemini AI
genai.configure(api_key="AIzaSyAyXEBdGOxciCDSItQRhru2BbNfbvZtyRs")
model = genai.GenerativeModel("gemini-1.5-pro")

# Initialize text-to-speech
engine = pyttsx3.init()
engine.setProperty('rate', 170)

def speak(text):
    engine.say(text)
    engine.runAndWait()

def listen():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        speak("Listening...")
        recognizer.adjust_for_ambient_noise(source)
        try:
            audio = recognizer.listen(source, timeout=5)
            return recognizer.recognize_google(audio).lower()
        except sr.UnknownValueError:
            return "Sorry, I couldn't understand."
        except sr.RequestError:
            return "API request failed."

def ask_jarvis(question):
    try:
        return model.generate_content(question).text
    except Exception as e:
        return f"Error: {str(e)}"

def open_website(command):
    if "open" in command:
        site = command.replace("open", "").strip()
        url = f"https://{site}.com"
        webbrowser.open(url)
        speak(f"Opening {site}")
        return f"Opening {site}"
    return None

def open_app(command):
    app_name = command.replace("open", "").strip()
    os.system(f"start {app_name}")
    speak(f"Opening {app_name}")
    return f"Opening {app_name}"

def close_app(command):
    app_name = command.replace("close", "").strip()
    os.system(f"taskkill /IM {app_name}.exe /F")
    speak(f"Closing {app_name}")
    return f"Closing {app_name}"

def control_laptop(command):
    actions = {
        "increase volume": "volume up",
        "decrease volume": "volume down",
        "mute": "volume mute",
        "take screenshot": lambda: pyautogui.screenshot().save("screenshot.png"),
        "lock laptop": "rundll32.exe user32.dll,LockWorkStation",
        "shutdown laptop": "shutdown /s /t 5",
        "restart laptop": "shutdown /r /t 5",
        "copy": lambda: pyperclip.copy(input_box.get()),
        "paste": lambda: input_box.insert("end", pyperclip.paste()),
    }
    for action in actions:
        if action in command:
            if callable(actions[action]):
                actions[action]()
            else:
                os.system(actions[action])
            speak(action.replace(" laptop", ""))
            return action.capitalize()
    return None

def get_weather(command):
    if "weather in" in command:
        city = command.replace("weather in", "").strip()
        url = f"http://api.weatherapi.com/v1/current.json?key=YOUR_WEATHER_API&q={city}"
        try:
            response = requests.get(url).json()
            weather = response['current']['condition']['text']
            temp = response['current']['temp_c']
            speak(f"The weather in {city} is {weather} with {temp} degrees Celsius.")
            return f"Weather in {city}: {weather}, {temp}°C"
        except:
            return "Could not fetch weather."
    return None

def send_message():
    command = input_box.get()
    input_box.delete(0, "end")
    handle_command(command)

def voice_command():
    update_chat("Listening...")
    command = listen()
    update_chat(f"You: {command}")
    handle_command(command)

def handle_command(command):
    if command in ["exit", "quit", "stop"]:
        speak("Goodbye, Sir!")
        app.quit()
    result = open_website(command) or open_app(command) or close_app(command) or control_laptop(command) or get_weather(command)
    if not result:
        result = ask_jarvis(command)
        speak(result)
    update_chat(f"You: {command}\nJ.A.R.V.I.S: {result}")

# UI Design
ctk.set_appearance_mode("dark")
app = ctk.CTk()
app.title("J.A.R.V.I.S AI")
app.geometry("600x700")

frame = ctk.CTkFrame(app)
frame.pack(pady=20, padx=20, fill="both", expand=True)

chat_box = ctk.CTkTextbox(frame, width=550, height=400, wrap="word")
chat_box.pack(pady=10, padx=10)
chat_box.insert("end", "J.A.R.V.I.S: Hello, Sir! How can I assist you?\n")

def update_chat(message):
    chat_box.insert("end", f"{message}\n")
    chat_box.see("end")

input_box = ctk.CTkEntry(app, width=400)
input_box.pack(pady=10)

send_button = ctk.CTkButton(app, text="Send", command=send_message)
send_button.pack(pady=5)

voice_button = ctk.CTkButton(app, text="🎙 Speak", command=voice_command)
voice_button.pack(pady=5)

app.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\customtkinter\windows\widgets\ctk_button.py", line 554, in _clicked
#     self._command()
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_19576\973086566.py", line 107, in voice_command
#     command = listen()
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_19576\973086566.py", line 30, in listen
#     audio = recognizer.listen(source, timeout=5)
#   File "C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\speech_recognition\__init__.py", line 460, in listen
#     for a in result:
#   File "C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\speech_recognition\__init__.py", line 490, in _listen
# ...

# %%
import google.generativeai as genai
import pyttsx3
import speech_recognition as sr
import pyautogui
import pywhatkit as kit
import wikipedia
import keyboard
import webbrowser
import time

# 🔹 Set up Gemini AI
genai.configure(api_key="AIzaSyAyXEBdGOxciCDSItQRhru2BbNfbvZtyRs")

def get_gemini_response(prompt, language="en"):
    """Get a short response from Gemini AI in the same language"""
    model = genai.GenerativeModel("gemini-1.5-pro")
    response = model.generate_content(prompt)
    return response.text.strip()

# 🔹 Set up Text-to-Speech
engine = pyttsx3.init()
engine.setProperty("rate", 170)

def speak(text):
    """Speak the text"""
    print("JARVIS:", text)
    engine.say(text)
    engine.runAndWait()

# 🔹 Voice Command Recognition
def listen():
    """Listen and return user command"""
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("🎤 Listening...")
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)

    try:
        command = recognizer.recognize_google(audio)
        print("You:", command)
        return command
    except sr.UnknownValueError:
        return "I didn't understand that"
    except sr.RequestError:
        return "Could not request results"

# 🔹 Open Apps & Websites
def open_website_or_app(command):
    if "open youtube" in command:
        webbrowser.open("https://www.youtube.com")
        speak("Opening YouTube")
    elif "open google" in command:
        webbrowser.open("https://www.google.com")
        speak("Opening Google")
    elif "open whatsapp" in command:
        pyautogui.hotkey("win", "s")
        time.sleep(1)
        pyautogui.write("WhatsApp")
        pyautogui.press("enter")
        speak("Opening WhatsApp")
    elif "open notepad" in command:
        pyautogui.hotkey("win", "r")
        time.sleep(1)
        pyautogui.write("notepad")
        pyautogui.press("enter")
        speak("Opening Notepad")
    elif "open file explorer" in command:
        pyautogui.hotkey("win", "e")
        speak("Opening File Explorer")
    elif "open settings" in command:
        pyautogui.hotkey("win", "i")
        speak("Opening Settings")
    else:
        speak("I can't open that yet.")

# 🔹 Send WhatsApp Message
def send_whatsapp_message():
    speak(" message to?")
    phone_number = listen().replace(" ", "")

    speak("What is the message?")
    message = listen()

    kit.sendwhatmsg_instantly(phone_number, message, wait_time=10)
    time.sleep(10)
    pyautogui.press("enter")
    speak("Message sent!")

# 🔹 Answer Any Question
def answer_question(command):
    response = get_gemini_response(command)
    speak(response)

# 🔹 Control Laptop with Voice
def control_laptop(command):
    if "increase volume" in command:
        keyboard.press_and_release("volume up")
        speak("Volume increased")
    elif "decrease volume" in command:
        keyboard.press_and_release("volume down")
        speak("Volume decreased")
    elif "mute" in command:
        keyboard.press_and_release("volume mute")
        speak("Muted")
    elif "play" in command or "pause" in command:
        keyboard.press_and_release("play/pause media")
        speak("Playing or pausing media")
    elif "lock the laptop" in command:
        keyboard.press_and_release("win + l")
        speak("Locking the laptop")
    elif "shutdown" in command:
        speak("Shutting down")
        pyautogui.hotkey("win", "x")
        time.sleep(1)
        pyautogui.press("u")
        pyautogui.press("u")
    elif "restart" in command:
        speak("Restarting")
        pyautogui.hotkey("win", "x")
        time.sleep(1)
        pyautogui.press("u")
        pyautogui.press("r")
    else:
        speak("I can't do that yet.")

# 🔹 Main Function
def jarvis():
    speak("Hello, I am JARVIS. How can I help you?")
    
    while True:
        command = listen().lower()

        if "open" in command:
            open_website_or_app(command)
        elif "send a whatsapp message" in command:
            send_whatsapp_message()
        elif "what is" in command or "who is" in command or "define" in command:
            answer_question(command)
        elif "increase volume" in command or "decrease volume" in command or "lock the laptop" in command:
            control_laptop(command)
        elif "exit" in command or "stop" in command:
            speak("Goodbye!")
            break
        else:
            speak("I didn't understand that.")

# 🔹 Run J.A.R.V.I.S.
if __name__ == "__main__":
    jarvis()
# Out:
# JARVIS: Hello, I am JARVIS. How can I help you?
# 🎤 Listening...
# You: exit
# JARVIS: Goodbye!

# %%
import google.generativeai as genai
import speech_recognition as sr
import pyttsx3
import webbrowser
import os
import keyboard
import pyautogui

genai.configure(api_key="AIzaSyAyXEBdGOxciCDSItQRhru2BbNfbvZtyRs")
model = genai.GenerativeModel("gemini-1.5-pro")

engine = pyttsx3.init()
engine.setProperty('rate', 170)

def speak(text):
    engine.say(text)
    engine.runAndWait()

def listen():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)
    try:
        return recognizer.recognize_google(audio).lower()
    except:
        return ""

def ask_jarvis(question):
    return model.generate_content(question).text

def open_website(command):
    sites = {
        "youtube": "https://youtube.com",
        "google": "https://google.com",
        "github": "https://github.com"
    }
    for site in sites:
        if site in command:
            webbrowser.open(sites[site])
            speak(f"Opening {site}")
            return True
    return False

def open_app(command):
    apps = {
        "notepad": "notepad.exe",
        "calculator": "calc.exe",
        "chrome": "C:\\Program Files\\Google\\Chrome\\Application\\chrome.exe"
    }
    for app in apps:
        if app in command:
            os.system(apps[app])
            speak(f"Opening {app}")
            return True
    return False

def control_laptop(command):
    if "increase volume" in command:
        keyboard.press_and_release("volume up")
        speak("Increasing volume")
    elif "decrease volume" in command:
        keyboard.press_and_release("volume down")
        speak("Decreasing volume")
    elif "mute" in command:
        keyboard.press_and_release("volume mute")
        speak("Muting volume")
    elif "take screenshot" in command:
        screenshot = pyautogui.screenshot()
        screenshot.save("screenshot.png")
        speak("Screenshot taken")
    elif "lock laptop" in command:
        os.system("rundll32.exe user32.dll,LockWorkStation")
        speak("Locking laptop")
    elif "shutdown laptop" in command:
        os.system("shutdown /s /t 5")
        speak("Shutting down in 5 seconds")
    elif "restart laptop" in command:
        os.system("shutdown /r /t 5")
        speak("Restarting in 5 seconds")
    else:
        return False
    return True

speak("Hello Sir, I am J.A.R.V.I.S. How can I assist you?")
while True:
    command = listen()

    if "exit" in command or "stop" in command:
        speak("Goodbye Sir")
        break

    elif open_website(command) or open_app(command) or control_laptop(command):
        continue

    else:
        response = ask_jarvis(command)
        speak(response)

# %%
import google.generativeai as genai
import speech_recognition as sr
import pyttsx3
import webbrowser
import os
import keyboard
import pyautogui
import cv2
import ffmpeg
import wikipedia
import time
import customtkinter as ctk
import pywhatkit as kit
import threading

# Configure Gemini AI
genai.configure(api_key="your_gemini_api_key")
model = genai.GenerativeModel("gemini-1.5-pro")

# Initialize TTS Engine
engine = pyttsx3.init()
engine.setProperty('rate', 170)

def speak(text):
    """Convert text to speech"""
    engine.say(text)
    engine.runAndWait()

def listen():
    """Listen to voice input"""
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)
    try:
        return recognizer.recognize_google(audio).lower()
    except:
        return ""

def ask_jarvis(question):
    """Get AI response"""
    return model.generate_content(question).text

def open_website(command):
    """Open websites"""
    sites = {
        "youtube": "https://youtube.com",
        "google": "https://google.com",
        "github": "https://github.com",
        "facebook": "https://facebook.com"
    }
    for site in sites:
        if site in command:
            webbrowser.open(sites[site])
            speak(f"Opening {site}")
            return f"Opening {site}"
    return None

def open_app(command):
    """Open applications"""
    apps = {
        "notepad": "notepad.exe",
        "calculator": "calc.exe",
        "chrome": "C:\\Program Files\\Google\\Chrome\\Application\\chrome.exe",
        "vlc": "C:\\Program Files\\VideoLAN\\VLC\\vlc.exe"
    }
    for app in apps:
        if app in command:
            os.system(apps[app])
            speak(f"Opening {app}")
            return f"Opening {app}"
    return None

def control_laptop(command):
    """Control laptop functions"""
    if "increase volume" in command:
        keyboard.press_and_release("volume up")
        speak("Increasing volume")
        return "Volume increased"
    elif "decrease volume" in command:
        keyboard.press_and_release("volume down")
        speak("Decreasing volume")
        return "Volume decreased"
    elif "mute" in command:
        keyboard.press_and_release("volume mute")
        speak("Muting volume")
        return "Volume muted"
    elif "take screenshot" in command:
        screenshot = pyautogui.screenshot()
        screenshot.save("screenshot.png")
        speak("Screenshot taken")
        return "Screenshot saved"
    elif "lock laptop" in command:
        os.system("rundll32.exe user32.dll,LockWorkStation")
        speak("Locking laptop")
        return "Laptop locked"
    elif "shutdown laptop" in command:
        os.system("shutdown /s /t 5")
        speak("Shutting down in 5 seconds")
        return "Shutting down"
    elif "restart laptop" in command:
        os.system("shutdown /r /t 5")
        speak("Restarting in 5 seconds")
        return "Restarting laptop"
    return None

def search_google(command):
    """Search Google"""
    query = command.replace("search", "").strip()
    speak(f"Searching Google for {query}")
    kit.search(query)
    return f"Searching Google for {query}"

def search_wikipedia(command):
    """Search Wikipedia"""
    query = command.replace("wikipedia", "").strip()
    speak(f"Searching Wikipedia for {query}")
    try:
        summary = wikipedia.summary(query, sentences=2)
        return summary
    except:
        return "No results found."

def start_screen_recording():
    """Start screen recording"""
    global recording, recorder
    recording = True
    recorder = cv2.VideoWriter("screen_recording.avi", cv2.VideoWriter_fourcc(*"XVID"), 10, pyautogui.size())

    while recording:
        frame = pyautogui.screenshot()
        frame = cv2.cvtColor(cv2.array(frame), cv2.COLOR_RGB2BGR)
        recorder.write(frame)
        time.sleep(0.1)

def stop_screen_recording():
    """Stop screen recording"""
    global recording, recorder
    recording = False
    recorder.release()
    speak("Screen recording saved as screen_recording.avi")
    return "Recording stopped"

def handle_command(command):
    """Process user commands"""
    if command in ["exit", "quit", "stop"]:
        speak("Goodbye, Sir!")
        app.quit()
    
    result = (open_website(command) or 
              open_app(command) or 
              control_laptop(command) or 
              search_google(command) or 
              search_wikipedia(command))

    if "start screen recording" in command:
        threading.Thread(target=start_screen_recording).start()
        result = "Screen recording started"
        speak(result)

    elif "stop screen recording" in command:
        result = stop_screen_recording()
        speak(result)

    if not result:
        result = ask_jarvis(command)
        speak(result)

    update_chat(f"You: {command}\nJ.A.R.V.I.S: {result}")

# UI Design
ctk.set_appearance_mode("dark")
app = ctk.CTk()
app.title("J.A.R.V.I.S AI")
app.geometry("600x700")

frame = ctk.CTkFrame(app)
frame.pack(pady=20, padx=20, fill="both", expand=True)

chat_box = ctk.CTkTextbox(frame, width=550, height=400, wrap="word")
chat_box.pack(pady=10, padx=10)
chat_box.insert("end", "J.A.R.V.I.S: Hello, Sir! How can I assist you?\n")

def update_chat(message):
    chat_box.insert("end", f"{message}\n")
    chat_box.see("end")

input_box = ctk.CTkEntry(app, width=400)
input_box.pack(pady=10)

def send_message():
    command = input_box.get()
    input_box.delete(0, "end")
    handle_command(command)

send_button = ctk.CTkButton(app, text="Send", command=send_message)
send_button.pack(pady=5)

def voice_command():
    update_chat("Listening...")
    command = listen()
    update_chat(f"You: {command}")
    handle_command(command)

voice_button = ctk.CTkButton(app, text="🎙 Speak", command=voice_command)
voice_button.pack(pady=5)

app.mainloop()

# %%
import google.generativeai as genai
import speech_recognition as sr
import pyttsx3
import webbrowser
import os
import keyboard
import pyautogui
import customtkinter as ctk
import time

# Configure Gemini AI
genai.configure(api_key="AIzaSyAyXEBdGOxciCDSItQRhru2BbNfbvZtyRs")
model = genai.GenerativeModel("gemini-1.5-pro")

# Initialize text-to-speech
engine = pyttsx3.init()
engine.setProperty('rate', 170)

def speak(text):
    engine.say(text)
    engine.runAndWait()

def listen():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)
    try:
        return recognizer.recognize_google(audio).lower()
    except:
        return ""

def ask_jarvis(question):
    response = model.generate_content(question).text
    return response.replace("*", "").strip()[:200]  # Removes * and shortens response

def open_website(command):
    if "open" in command:
        site_name = command.replace("open ", "").strip()
        url = f"https://www.{site_name}.com"
        webbrowser.open(url)
        speak(f"Opening {site_name}")
        return f"Opening {site_name}"
    return None

def open_app(command):
    apps = {
        "notepad": "notepad.exe",
        "calculator": "calc.exe",
        "chrome": "C:\\Program Files\\Google\\Chrome\\Application\\chrome.exe",
        "whatsapp": "C:\\Users\\admin\\AppData\\Local\\WhatsApp\\WhatsApp.exe",
        "vs code": "C:\\Users\\admin\\AppData\\Local\\Programs\\Microsoft VS Code\\Code.exe",
        "android studio": "C:\\Program Files\\Android\\Android Studio\\bin\\studio64.exe",
        "powershell": "powershell.exe",
        "file explorer": "explorer.exe",
        "clock": "timedate.cpl",
        "omen": "C:\\Program Files\\HP\\OMEN Gaming Hub\\OmenGamingHub.exe",
        "settings": "ms-settings:"
    }
    for app in apps:
        if app in command:
            os.system(f'start {apps[app]}')
            speak(f"Opening {app}")
            return f"Opening {app}"
    return None

def control_laptop(command):
    if "increase volume" in command:
        keyboard.press_and_release("volume up")
        speak("Increasing volume")
        return "Volume increased"
    elif "decrease volume" in command:
        keyboard.press_and_release("volume down")
        speak("Decreasing volume")
        return "Volume decreased"
    elif "mute" in command:
        keyboard.press_and_release("volume mute")
        speak("Muting volume")
        return "Volume muted"
    elif "take screenshot" in command:
        screenshot = pyautogui.screenshot()
        screenshot.save("screenshot.png")
        speak("Screenshot taken")
        return "Screenshot saved"
    elif "lock laptop" in command:
        os.system("rundll32.exe user32.dll,LockWorkStation")
        speak("Locking laptop")
        return "Laptop locked"
    elif "shutdown laptop" in command:
        os.system("shutdown /s /t 5")
        speak("Shutting down in 5 seconds")
        return "Shutting down"
    elif "restart laptop" in command:
        os.system("shutdown /r /t 5")
        speak("Restarting in 5 seconds")
        return "Restarting laptop"
    return None

def youtube_controls(command):
    if "search youtube for" in command:
        query = command.replace("search youtube for", "").strip()
        webbrowser.open(f"https://www.youtube.com/results?search_query={query}")
        speak(f"Searching YouTube for {query}")
        return f"Searching YouTube for {query}"
    elif "play youtube" in command:
        keyboard.press("k")
        speak("Playing YouTube video")
        return "Playing YouTube"
    elif "pause youtube" in command:
        keyboard.press("k")
        speak("Pausing YouTube video")
        return "Pausing YouTube"
    elif "next youtube" in command:
        keyboard.press("shift+N")
        speak("Skipping to next video")
        return "Next YouTube video"
    return None

def spotify_controls(command):
    if "search spotify for" in command:
        query = command.replace("search spotify for", "").strip()
        webbrowser.open(f"https://open.spotify.com/search/{query.replace(' ', '%20')}")
        speak(f"Searching Spotify for {query}")
        return f"Searching Spotify for {query}"
    elif "play spotify" in command:
        keyboard.press("space")
        speak("Playing song on Spotify")
        return "Playing Spotify"
    elif "pause spotify" in command:
        keyboard.press("space")
        speak("Pausing song on Spotify")
        return "Pausing Spotify"
    elif "next spotify" in command:
        keyboard.press("ctrl+right")
        speak("Skipping to next song")
        return "Next Spotify song"
    return None

def handle_command(command):
    if command in ["exit", "quit", "stop"]:
        speak("Goodbye, Sir!")
        app.quit()
    result = (
        open_website(command) or 
        open_app(command) or 
        control_laptop(command) or
        youtube_controls(command) or
        spotify_controls(command)
    )
    if not result:
        result = ask_jarvis(command)
        speak(result)
    update_chat(f"You: {command}\nJ.A.R.V.I.S: {result}")

# UI Design
ctk.set_appearance_mode("dark")
app = ctk.CTk()
app.title("J.A.R.V.I.S AI")
app.geometry("600x700")

frame = ctk.CTkFrame(app)
frame.pack(pady=20, padx=20, fill="both", expand=True)

chat_box = ctk.CTkTextbox(frame, width=550, height=400, wrap="word")
chat_box.pack(pady=10, padx=10)
chat_box.insert("end", "J.A.R.V.I.S: Hello, Admin! How can I assist you?\n")

def update_chat(message):
    chat_box.insert("end", f"{message}\n")
    chat_box.see("end")

input_box = ctk.CTkEntry(app, width=400)
input_box.pack(pady=10)

def send_message():
    command = input_box.get()
    input_box.delete(0, "end")
    handle_command(command)

send_button = ctk.CTkButton(app, text="Send", command=send_message)
send_button.pack(pady=5)

def voice_command():
    update_chat("Listening...")
    command = listen()
    update_chat(f"You: {command}")
    handle_command(command)

voice_button = ctk.CTkButton(app, text="🎙 Speak", command=voice_command)
voice_button.pack(pady=5)

app.mainloop()

# %%
import google.generativeai as genai
import speech_recognition as sr
import pyttsx3
import webbrowser
import os
import keyboard
import pyautogui
import customtkinter as ctk
import time

# Configure Gemini AI
genai.configure(api_key="AIzaSyAyXEBdGOxciCDSItQRhru2BbNfbvZtyRs")
model = genai.GenerativeModel("gemini-1.5-pro")

# Initialize text-to-speech
engine = pyttsx3.init()
engine.setProperty('rate', 170)

def speak(text):
    engine.say(text)
    engine.runAndWait()

def listen():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)
    try:
        return recognizer.recognize_google(audio).lower()
    except:
        return ""

def ask_jarvis(question):
    response = model.generate_content(question).text
    return response.replace("*", "").strip()[:200]  # Removes * and shortens response

def open_website(command):
    websites = {
        "google": "https://www.google.com",
        "youtube": "https://www.youtube.com",
        "facebook": "https://www.facebook.com",
        "twitter": "https://www.twitter.com",
        "instagram": "https://www.instagram.com"
    }
    for site in websites:
        if site in command:
            webbrowser.open(websites[site])
            speak(f"Opening {site}")
            return f"Opening {site}"
    return None

def open_app(command):
    apps = {
        "notepad": "notepad.exe",
        "calculator": "calc.exe",
        "chrome": "C:\\Program Files\\Google\\Chrome\\Application\\chrome.exe",
        "whatsapp": "C:\\Users\\admin\\AppData\\Local\\WhatsApp\\WhatsApp.exe",
        "vs code": "C:\\Users\\admin\\AppData\\Local\\Programs\\Microsoft VS Code\\Code.exe"
    }
    for app in apps:
        if app in command:
            os.system(f'start {apps[app]}')
            speak(f"Opening {app}")
            return f"Opening {app}"
    return None

def handle_command(command):
    if command in ["exit", "quit", "stop"]:
        speak("Goodbye, Sir!")
        app.quit()
    result = open_website(command) or open_app(command)
    if not result:
        result = ask_jarvis(command)
        speak(result)
    update_chat(f"You: {command}\nJ.A.R.V.I.S: {result}")

# UI Design
ctk.set_appearance_mode("dark")
app = ctk.CTk()
app.title("J.A.R.V.I.S AI")
app.geometry("600x700")

frame = ctk.CTkFrame(app)
frame.pack(pady=20, padx=20, fill="both", expand=True)

chat_box = ctk.CTkTextbox(frame, width=550, height=400, wrap="word")
chat_box.pack(pady=10, padx=10)
chat_box.insert("end", "J.A.R.V.I.S: Hello, Admin! How can I assist you?\n")

def update_chat(message):
    chat_box.insert("end", f"{message}\n")
    chat_box.see("end")

input_box = ctk.CTkEntry(app, width=400)
input_box.pack(pady=10)

def send_message():
    command = input_box.get()
    input_box.delete(0, "end")
    handle_command(command)

send_button = ctk.CTkButton(app, text="Send", command=send_message)
send_button.pack(pady=5)

def voice_command():
    update_chat("Listening...")
    command = listen()
    update_chat(f"You: {command}")
    handle_command(command)

voice_button = ctk.CTkButton(app, text="🎙 Speak", command=voice_command)
voice_button.pack(pady=5)

app.mainloop()

# %%
import os
import webbrowser
import speech_recognition as sr
import pyttsx3
import google.generativeai as genai
import pyautogui

# Initialize Text-to-Speech Engine
engine = pyttsx3.init()
engine.setProperty("rate", 170)
engine.setProperty("volume", 1.0)

# Configure Google Gemini AI (Replace with your API key)
genai.configure(api_key="AIzaSyAyXEBdGOxciCDSItQRhru2BbNfbvZtyRs")

def speak(text):
    """Convert text to speech."""
    engine.say(text)
    engine.runAndWait()

def recognize_speech():
    """Convert voice input to text."""
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)

    try:
        command = recognizer.recognize_google(audio).lower()
        print(f"You said: {command}")
        return command
    except sr.UnknownValueError:
        speak("Sorry, I didn't catch that.")
        return ""
    except sr.RequestError:
        speak("Could not connect to the speech service.")
        return ""

def open_app(command):
    """Open installed applications based on voice command."""
    apps = {
        "notepad": "notepad.exe",
        "calculator": "calc.exe",
        "chrome": "C:\\Program Files\\Google\\Chrome\\Application\\chrome.exe",
        "whatsapp": "C:\\Users\\admin\\AppData\\Local\\WhatsApp\\WhatsApp.exe",
        "vs code": "C:\\Users\\admin\\AppData\\Local\\Programs\\Microsoft VS Code\\Code.exe",
        "android studio": "C:\\Program Files\\Android\\Android Studio\\bin\\studio64.exe",
        "powershell": "powershell.exe",
        "file explorer": "explorer.exe",
        "clock": "timedate.cpl",
        "settings": "ms-settings:"
    }

    for app in apps:
        if app in command:
            try:
                os.startfile(apps[app])
                speak(f"Opening {app}")
                return f"Opening {app}"
            except FileNotFoundError:
                speak(f"Sorry, I couldn't find {app}")
                return f"Error: {app} not found"
    
    return None

def open_website(command):
    """Open websites when requested."""
    if "open" in command and "." in command:
        site_name = command.replace("open ", "").strip()
        url = f"https://{site_name}"
        webbrowser.open(url)
        speak(f"Opening {site_name}")
        return f"Opening {site_name}"
    elif "open" in command:
        sites = {
            "google": "https://www.google.com",
            "youtube": "https://www.youtube.com",
            "github": "https://www.github.com",
            "facebook": "https://www.facebook.com",
            "twitter": "https://www.twitter.com"
        }
        site_name = command.replace("open ", "").strip()
        if site_name in sites:
            webbrowser.open(sites[site_name])
            speak(f"Opening {site_name}")
            return f"Opening {site_name}"
    return None

def system_commands(command):
    """Perform basic system control functions."""
    if "shutdown" in command:
        speak("Shutting down your computer.")
        os.system("shutdown /s /t 5")
    elif "restart" in command:
        speak("Restarting your computer.")
        os.system("shutdown /r /t 5")
    elif "lock" in command:
        speak("Locking your computer.")
        os.system("rundll32.exe user32.dll,LockWorkStation")
    elif "sleep" in command:
        speak("Putting your computer to sleep.")
        os.system("rundll32.exe powrprof.dll,SetSuspendState 0,1,0")
    elif "volume up" in command:
        pyautogui.press("volumeup", presses=5)
        speak("Increasing volume.")
    elif "volume down" in command:
        pyautogui.press("volumedown", presses=5)
        speak("Decreasing volume.")
    elif "mute" in command:
        pyautogui.press("volumemute")
        speak("Muting volume.")
    elif "brightness up" in command:
        pyautogui.press("brightnessup", presses=3)
        speak("Increasing brightness.")
    elif "brightness down" in command:
        pyautogui.press("brightnessdown", presses=3)
        speak("Decreasing brightness.")
    else:
        return None
    return True

def ask_gemini(prompt):
    """Get AI-generated responses from Google Gemini 1.5 Pro."""
    model = genai.GenerativeModel("gemini-1.5-pro")
    response = model.generate_content(prompt)
    if response.text:
        clean_response = response.text.replace("*", "").strip()  # Remove asterisks
        return clean_response
    return "I couldn't find an answer."

def main():
    """Main loop to listen for commands and respond accordingly."""
    speak("Hello, I am Jarvis. How can I assist you?")
    
    while True:
        command = recognize_speech()

        if "exit" in command or "stop" in command or "goodbye" in command:
            speak("Goodbye! Have a great day!")
            break

        if "open" in command:
            response = open_app(command) or open_website(command)
            if response:
                print(response)
                continue

        elif any(keyword in command for keyword in ["shutdown", "restart", "lock", "sleep", "volume", "brightness", "mute"]):
            if system_commands(command):
                continue

        elif "search" in command or "who is" in command or "what is" in command:
            query = command.replace("search", "").replace("who is", "").replace("what is", "").strip()
            response = ask_gemini(query)
            speak(response)
            print(response)
            continue

        else:
            speak("I didn't understand that command. Can you repeat?")
        
if __name__ == "__main__":
    main()
# Out:
# Listening...

# %%
import os
import webbrowser
import speech_recognition as sr
import pyttsx3
import google.generativeai as genai
import pyautogui
import tkinter as tk
from tkinter import messagebox

genai.configure(api_key="AIzaSyAyXEBdGOxciCDSItQRhru2BbNfbvZtyRs")
engine = pyttsx3.init()
engine.setProperty("rate", 170)
engine.setProperty("volume", 1.0)

def speak(text):
    engine.say(text)
    engine.runAndWait()

def recognize_speech():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)
    try:
        return recognizer.recognize_google(audio).lower()
    except:
        return ""

def open_app(app):
    apps = {
        "notepad": "notepad.exe",
        "calculator": "calc.exe",
        "word": "C:\\Program Files\\Microsoft Office\\root\\Office16\\WINWORD.EXE",
        "excel": "C:\\Program Files\\Microsoft Office\\root\\Office16\\EXCEL.EXE",
        "powerpoint": "C:\\Program Files\\Microsoft Office\\root\\Office16\\POWERPNT.EXE",
        "outlook": "C:\\Program Files\\Microsoft Office\\root\\Office16\\OUTLOOK.EXE",
        "onenote": "C:\\Program Files\\Microsoft Office\\root\\Office16\\ONENOTE.EXE",
        "chrome": "C:\\Program Files\\Google\\Chrome\\Application\\chrome.exe",
        "vs code": "C:\\Users\\admin\\AppData\\Local\\Programs\\Microsoft VS Code\\Code.exe",
        "android studio": "C:\\Program Files\\Android\\Android Studio\\bin\\studio64.exe",
        "powershell": "powershell.exe",
        "cmd": "cmd.exe"
    }
    if app in apps:
        os.startfile(apps[app])
        speak(f"Opening {app}")

def open_website(site):
    sites = {
        "google": "https://www.google.com",
        "youtube": "https://www.youtube.com",
        "github": "https://www.github.com"
    }
    if site in sites:
        webbrowser.open(sites[site])
        speak(f"Opening {site}")

def ask_gemini(prompt):
    model = genai.GenerativeModel("gemini-1.5-pro")
    response = model.generate_content(prompt)
    return response.text.replace("*", "").strip()

def gui_interface():
    root = tk.Tk()
    root.title("Jarvis AI Assistant")
    root.geometry("400x500")
    
    def execute_command():
        command = entry.get().lower()
        if "open" in command:
            app = command.replace("open ", "").strip()
            open_app(app)
        elif "search" in command:
            result = ask_gemini(command.replace("search ", "").strip())
            messagebox.showinfo("Gemini AI", result)
            speak(result)
        elif "website" in command:
            site = command.replace("open ", "").strip()
            open_website(site)
        elif "exit" in command:
            root.destroy()
        else:
            speak("Command not recognized")
    
    label = tk.Label(root, text="Enter command:")
    label.pack(pady=10)
    entry = tk.Entry(root, width=40)
    entry.pack()
    button = tk.Button(root, text="Execute", command=execute_command)
    button.pack(pady=20)
    root.mainloop()

gui_interface()

# %%
import os
import webbrowser
import speech_recognition as sr
import pyttsx3
import google.generativeai as genai
import customtkinter as ctk
from tkinter import messagebox

# Configure Gemini API
API_KEY = "AIzaSyAyXEBdGOxciCDSItQRhru2BbNfbvZtyRs"
if API_KEY:
    genai.configure(api_key=API_KEY)
else:
    print("Error: Gemini API key is missing.")

# Initialize text-to-speech engine
engine = pyttsx3.init()
engine.setProperty("rate", 170)
engine.setProperty("volume", 1.0)

def speak(text):
    engine.say(text)
    engine.runAndWait()

def recognize_speech():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        try:
            audio = recognizer.listen(source, timeout=5)
            return recognizer.recognize_google(audio).lower()
        except sr.UnknownValueError:
            return ""
        except sr.RequestError:
            return ""

def open_app(app):
    apps = {
        "notepad": "notepad.exe",
        "calculator": "calc.exe",
        "word": "C:\\Program Files\\Microsoft Office\\root\\Office16\\WINWORD.EXE",
        "excel": "C:\\Program Files\\Microsoft Office\\root\\Office16\\EXCEL.EXE",
        "chrome": "C:\\Program Files\\Google\\Chrome\\Application\\chrome.exe",
        "vs code": "C:\\Users\\admin\\AppData\\Local\\Programs\\Microsoft VS Code\\Code.exe",
    }
    if app in apps:
        os.startfile(apps[app])
        speak(f"Opening {app}")
    else:
        speak("Application not found")

def open_website(site):
    sites = {
        "google": "https://www.google.com",
        "youtube": "https://www.youtube.com",
        "github": "https://www.github.com"
    }
    if site in sites:
        webbrowser.open(sites[site])
        speak(f"Opening {site}")
    else:
        speak("Website not found")

def ask_gemini(prompt):
    try:
        model = genai.GenerativeModel("gemini-1.5-pro")
        response = model.generate_content(prompt)
        return response.text.replace("*", "").strip()
    except Exception as e:
        return f"Error communicating with Gemini API: {str(e)}"

def gui_interface():
    ctk.set_appearance_mode("dark")
    ctk.set_default_color_theme("blue")
    
    root = ctk.CTk()
    root.title("Jarvis AI Assistant")
    root.geometry("500x600")
    
def gui_interface():
    root = tk.Tk()
    root.title("Jarvis AI Assistant")
    root.geometry("400x500")
    
    def execute_command():
        command = entry.get().lower()
        if "open" in command:
            app = command.replace("open ", "").strip()
            open_app(app)
        elif "search" in command:
            result = ask_gemini(command.replace("search ", "").strip())
            messagebox.showinfo("Gemini AI", result)
            speak(result)
        elif "website" in command:
            site = command.replace("open ", "").strip()
            open_website(site)
        elif "exit" in command:
            root.destroy()
        else:
            speak("Command not recognized")
    
    def voice_command():
        command = recognize_speech()
        if command:
            entry.delete(0, "end")
            entry.insert(0, command)
            execute_command()
        else:
            speak("Sorry, I didn't catch that.")
    
    title_label = ctk.CTkLabel(root, text="Jarvis AI Assistant", font=("Arial", 20))
    title_label.pack(pady=10)
    
    entry = ctk.CTkEntry(root, width=350, height=40, font=("Arial", 14))
    entry.pack(pady=10)
    
    button_frame = ctk.CTkFrame(root)
    button_frame.pack(pady=10)
    
    execute_btn = ctk.CTkButton(button_frame, text="Execute", command=execute_command)
    execute_btn.grid(row=0, column=0, padx=5)
    
    voice_btn = ctk.CTkButton(button_frame, text="🎙️ Voice Command", command=voice_command)
    voice_btn.grid(row=0, column=1, padx=5)
    
    output_textbox = ctk.CTkTextbox(root, width=450, height=250, font=("Arial", 14), state="disabled")
    output_textbox.pack(pady=10)
    
    root.mainloop()

gui_interface()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 131
#     127     output_textbox.pack(pady=10)
#     129     root.mainloop()
# --> 131 gui_interface()
#
# Cell In[1], line 81, in gui_interface()
#      80 def gui_interface():
# ---> 81     root = tk.Tk()
#      82     root.title("Jarvis AI Assistant")
#      83     root.geometry("400x500")
#
# NameError: name 'tk' is not defined

# %%
import os
import webbrowser
import speech_recognition as sr
import pyttsx3
import google.generativeai as genai
import pyautogui
import tkinter as tk
from tkinter import scrolledtext

# Initialize TTS engine
engine = pyttsx3.init()
engine.setProperty("rate", 170)
engine.setProperty("volume", 1.0)

# Configure Google Gemini AI
GENAI_API_KEY = os.getenv("AIzaSyAyXEBdGOxciCDSItQRhru2BbNfbvZtyRs")  # Use environment variable for security
if GENAI_API_KEY:
    genai.configure(api_key=GENAI_API_KEY)

def speak(text):
    """Convert text to speech."""
    engine.say(text)
    engine.runAndWait()

def recognize_speech():
    """Convert voice input to text."""
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        speak("Listening...")
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)

    try:
        return recognizer.recognize_google(audio).lower()
    except sr.UnknownValueError:
        return ""
    except sr.RequestError:
        return ""

def open_app(command):
    """Open installed applications based on voice command."""
    apps = {
        "notepad": "notepad.exe",
        "calculator": "calc.exe",
        "chrome": "C:\\Program Files\\Google\\Chrome\\Application\\chrome.exe",
        "vs code": "C:\\Users\\admin\\AppData\\Local\\Programs\\Microsoft VS Code\\Code.exe",
        "file explorer": "explorer.exe"
    }
    for app, path in apps.items():
        if app in command:
            os.startfile(path)
            return f"Opening {app}"
    return None

def open_website(command):
    """Open websites when requested."""
    if "open" in command and "." in command:
        site_name = command.replace("open ", "").strip()
        webbrowser.open(f"https://{site_name}")
        return f"Opening {site_name}"
    return None

def system_commands(command):
    """Perform basic system control functions."""
    if "shutdown" in command:
        os.system("shutdown /s /t 5")
    elif "restart" in command:
        os.system("shutdown /r /t 5")
    elif "lock" in command:
        os.system("rundll32.exe user32.dll,LockWorkStation")
    elif "volume up" in command:
        pyautogui.press("volumeup", presses=5)
    elif "volume down" in command:
        pyautogui.press("volumedown", presses=5)
    elif "mute" in command:
        pyautogui.press("volumemute")
    else:
        return None
    return True

def ask_gemini(prompt):
    """Get AI-generated responses from Google Gemini."""
    if not GENAI_API_KEY:
        return "Gemini API key missing."
    model = genai.GenerativeModel("gemini-1.5-pro")
    response = model.generate_content(prompt)
    return response.text if response.text else "No response."

def process_command(command):
    """Process user commands."""
    response = open_app(command) or open_website(command)
    if response:
        return response
    if system_commands(command):
        return "Executing system command."
    if "search" in command or "who is" in command or "what is" in command:
        return ask_gemini(command.replace("search", "").strip())
    return "Command not recognized."

# GUI Setup
def run_gui():
    root = tk.Tk()
    root.title("Jarvis AI Assistant")
    root.geometry("500x600")

    output_box = scrolledtext.ScrolledText(root, wrap=tk.WORD, width=60, height=20)
    output_box.pack(pady=10)
    
    def execute_command():
        command = command_entry.get().lower()
        output = process_command(command)
        speak(output)
        output_box.insert(tk.END, f"You: {command}\nJarvis: {output}\n\n")
        command_entry.delete(0, tk.END)

    command_entry = tk.Entry(root, width=50)
    command_entry.pack(pady=5)
    tk.Button(root, text="Run", command=execute_command).pack()
    root.mainloop()

if __name__ == "__main__":
    run_gui()
